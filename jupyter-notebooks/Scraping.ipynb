# %%
import json
import time
import requests
from bs4 import BeautifulSoup
import lyricsgenius
import os
import sqlite3

# %%
# Dein API-Schlüssel
CLIENT_ACCESS_TOKEN = '0NuDs36z70ithLwO3QTBQmsnofB1Ykb_yIWKFuLMZwIdjkzaxuKr3k763n_jIua-'

# Initialisiere die Genius-API
genius = lyricsgenius.Genius(CLIENT_ACCESS_TOKEN, timeout=20, sleep_time=0.2, retries=3)

def get_all_artists():
    artist_names = []
    base_artist_url = "https://genius.com/artists-index/{}"

    for letter in 'abcdefghijklmnopqrstuvwxyz':
        url = base_artist_url.format(letter)
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')

        for a in soup.find_all('a', class_='artists_index_list-artist_name'):
            artist_names.append(a.get_text())

        for ul in soup.find_all('ul', class_='artists_index_list'):
            for a in ul.find_all('a'):
                artist_names.append(a.get_text())

    return artist_names

def get_artist_id(artist_name):
    search_results = genius.search_artists(artist_name)
    if 'sections' in search_results and len(search_results['sections']) > 0:
        for hit in search_results['sections'][0]['hits']:
            if hit['result']['name'].lower() == artist_name.lower():
                return hit['result']['id']
    return None

def get_artist_songs(artist_id):
    songs = genius.artist_songs(artist_id, per_page=50, sort='title')
    song_ids = [song['id'] for song in songs['songs']]
    return song_ids


def contains_problematic_chars(text):
    # Definiere problematische Zeichen oder Muster
    problematic_chars = ["\u200b", "\u00e4", "\u00f6", "\u00fc", "\u00df"]  # Beispiel: Unicode-Zeichen
    return any(char in text for char in problematic_chars)


def get_song_details(song_id):
    retries = 5
    while retries > 0:
        try:
            song = genius.song(song_id)
            
            # Abrufen der gewünschten Informationen
            title = song['song']['title']
            artist = song['song']['primary_artist']['name']
            release_date = song['song']['release_date'] if 'release_date' in song['song'] else "Unknown"
            album = song['song']['album']['name'] if song['song']['album'] else "Single"
            popularity = song['song']['stats']['pageviews'] if 'stats' in song['song'] and 'pageviews' in song['song']['stats'] else "Unknown"

            # Überprüfe auf problematische Zeichen
            if contains_problematic_chars(title) or contains_problematic_chars(artist):
                print(f"Skipping song ID {song_id} due to problematic characters in title or artist.")
                return None
            
            # Liedtext extrahieren
            lyrics = genius.lyrics(song_id)
            if not lyrics or lyrics.strip() == "":
                lyrics = "Lyrics not available"
            
            # Rückgabe der Informationen in einem Dictionary
            return {
                'song_id': song_id,
                'title': title,
                'artist': artist,
                'release_date': release_date,
                'lyrics': lyrics,
                'album': album,
                'popularity': popularity
            }
        except requests.exceptions.Timeout:
            retries -= 1
            print(f"Timeout occurred. Retrying... ({5 - retries}/5)")
            time.sleep(2)
        except Exception as e:
            print(f"Error getting details for song ID {song_id}: {e}")
            return None



def save_checkpoint(data, filename):
    with open(filename, 'w') as f:
        json.dump(data, f)

def load_checkpoint(filename):
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            return json.load(f)
    return None

# %%
# Schritt 1: Künstlernamen abrufen
artist_names_checkpoint = load_checkpoint('artist_names.json')
if artist_names_checkpoint is None:
    artist_names = get_all_artists()
    save_checkpoint(artist_names, 'artist_names.json')
else:
    artist_names = artist_names_checkpoint

# Schritt 2: Künstler-IDs und Songs abrufen
song_ids_list_checkpoint = load_checkpoint('song_ids_list.json')
if song_ids_list_checkpoint is None:
    song_ids_list  = []
    processed_artists = 0
else:
    song_ids_list = song_ids_list_checkpoint['song_ids']
    processed_artists = song_ids_list_checkpoint['processed_artists']

for index, artist_name in enumerate(artist_names[processed_artists:], start=processed_artists):
    artist_id = get_artist_id(artist_name)
    if artist_id:
        song_ids = get_artist_songs(artist_id)
        song_ids_list.extend(song_ids)

    # Checkpoint nach jedem Künstler speichern
    save_checkpoint({'song_ids': song_ids_list, 'processed_artists': index + 1}, 'song_ids_list.json')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 21
#      19 artist_id = get_artist_id(artist_name)
#      20 if artist_id:
# ---> 21     song_ids = get_artist_songs(artist_id)
#      22     song_ids_list.extend(song_ids)
#      24 # Checkpoint nach jedem Künstler speichern
#
# Cell In[20], line 34, in get_artist_songs(artist_id)
#      33 def get_artist_songs(artist_id):
# ---> 34     songs = genius.artist_songs(artist_id, per_page=50, sort='title')
#      35     song_ids = [song['id'] for song in songs['songs']]
#      36     return song_ids
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/lyricsgenius/api/api.py:349, in API.artist_songs(self, artist_id, per_page, page, sort)
#     344 endpoint = "artists/{id}/songs".format(id=artist_id)
#     346 params = {'sort': sort,
#     347           'per_page': per_page,
#     348           'page': page}
# --> 349 return self._make_request(endpoint, params_=params)
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/lyricsgenius/api/base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      73 tries += 1
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#      81 except Timeout as e:
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Lade die vorhandene JSON-Datei mit den Song-IDs und entferne Duplikate
filename = 'song_ids_list.json'
data = load_checkpoint(filename)
unique_song_ids = list(set(data['song_ids']))

# %%
# Lade den Checkpoint für die Song-Details
details_checkpoint = load_checkpoint('song_details_checkpoint.json')
if details_checkpoint is None:
    song_details_list = []
    processed_songs = 0
else:
    song_details_list = details_checkpoint['song_details']
    processed_songs = details_checkpoint['processed_songs']

# Abrufen der Song-Details und Speichern der Checkpoints
for index, song_id in enumerate(unique_song_ids[processed_songs:], start=processed_songs):
    details = get_song_details(song_id)
    if details:
        song_details_list.append(details)
    
    # Checkpoint nach jedem Song speichern
    save_checkpoint({'song_details': song_details_list, 'processed_songs': index + 1}, 'song_details_checkpoint.json')
# Out:
# Skipping song ID 3201397 due to problematic characters in title or artist.
# Skipping song ID 10541437 due to problematic characters in title or artist.
# Skipping song ID 8444353 due to problematic characters in title or artist.
# Skipping song ID 5298630 due to problematic characters in title or artist.
# Skipping song ID 6347259 due to problematic characters in title or artist.
# Skipping song ID 1104393 due to problematic characters in title or artist.
# Skipping song ID 9493004 due to problematic characters in title or artist.
# Skipping song ID 3201576 due to problematic characters in title or artist.
# Skipping song ID 5298764 due to problematic characters in title or artist.
# Skipping song ID 9493110 due to problematic characters in title or artist.
# Skipping song ID 8444573 due to problematic characters in title or artist.
# Skipping song ID 5298893 due to problematic characters in title or artist.
# Skipping song ID 4250322 due to problematic characters in title or artist.
# Skipping song ID 10541779 due to problematic characters in title or artist.
# Skipping song ID 5298950 due to problematic characters in title or artist.
# Skipping song ID 8444763 due to problematic characters in title or artist.
# Skipping song ID 10542086 due to problematic characters in title or artist.
# Skipping song ID 5299240 due to problematic characters in title or artist.
# Skipping song ID 3202093 due to problematic characters in title or artist.
# Skipping song ID 2153611 due to problematic characters in title or artist.
# Skipping song ID 5299378 due to problematic characters in title or artist.
# Skipping song ID 3202388 due to problematic characters in title or artist.
# Skipping song ID 10542486 due to problematic characters in title or artist.
# Skipping song ID 8445355 due to problematic characters in title or artist.
# Skipping song ID 8445386 due to problematic characters in title or artist.
# Skipping song ID 8445428 due to problematic characters in title or artist.
# Skipping song ID 8445430 due to problematic characters in title or artist.
# Skipping song ID 8445429 due to problematic characters in title or artist.
# Skipping song ID 8445427 due to problematic characters in title or artist.
# Skipping song ID 8445452 due to problematic characters in title or artist.
# Skipping song ID 8445453 due to problematic characters in title or artist.
# Skipping song ID 8445454 due to problematic characters in title or artist.
# Skipping song ID 8445482 due to problematic characters in title or artist.
# Skipping song ID 10542652 due to problematic characters in title or artist.
# Skipping song ID 56908 due to problematic characters in title or artist.
# Skipping song ID 6348366 due to problematic characters in title or artist.
# Skipping song ID 7396956 due to problematic characters in title or artist.
# Skipping song ID 5299817 due to problematic characters in title or artist.
# Skipping song ID 7396971 due to problematic characters in title or artist.
# Skipping song ID 9494127 due to problematic characters in title or artist.
# Skipping song ID 7396979 due to problematic characters in title or artist.
# Skipping song ID 4251257 due to problematic characters in title or artist.
# Skipping song ID 10542742 due to problematic characters in title or artist.
# Skipping song ID 4251291 due to problematic characters in title or artist.
# Skipping song ID 4251290 due to problematic characters in title or artist.
# Skipping song ID 4251292 due to problematic characters in title or artist.
# Skipping song ID 4251294 due to problematic characters in title or artist.
# Skipping song ID 4251295 due to problematic characters in title or artist.
# Skipping song ID 4251297 due to problematic characters in title or artist.
# Skipping song ID 10542746 due to problematic characters in title or artist.
# Skipping song ID 4251301 due to problematic characters in title or artist.
# Skipping song ID 5299910 due to problematic characters in title or artist.
# Skipping song ID 4251358 due to problematic characters in title or artist.
# Skipping song ID 4251359 due to problematic characters in title or artist.
# Skipping song ID 4251361 due to problematic characters in title or artist.
# Skipping song ID 8445667 due to problematic characters in title or artist.
# Skipping song ID 4251366 due to problematic characters in title or artist.
# Skipping song ID 4251383 due to problematic characters in title or artist.
# Skipping song ID 4251400 due to problematic characters in title or artist.
# Skipping song ID 5299992 due to problematic characters in title or artist.
# Skipping song ID 4251421 due to problematic characters in title or artist.
# Skipping song ID 4251423 due to problematic characters in title or artist.
# Skipping song ID 4251425 due to problematic characters in title or artist.
# Skipping song ID 4251427 due to problematic characters in title or artist.
# Skipping song ID 4251428 due to problematic characters in title or artist.
# Skipping song ID 4251429 due to problematic characters in title or artist.
# Skipping song ID 4251435 due to problematic characters in title or artist.
# Skipping song ID 4251436 due to problematic characters in title or artist.
# Skipping song ID 5300028 due to problematic characters in title or artist.
# Skipping song ID 1105738 due to problematic characters in title or artist.
# Skipping song ID 1105783 due to problematic characters in title or artist.
# Skipping song ID 10542977 due to problematic characters in title or artist.
# Skipping song ID 7397273 due to problematic characters in title or artist.
# Skipping song ID 10543017 due to problematic characters in title or artist.
# Skipping song ID 7397301 due to problematic characters in title or artist.
# Skipping song ID 57285 due to problematic characters in title or artist.
# Skipping song ID 7397339 due to problematic characters in title or artist.
# Skipping song ID 57348 due to problematic characters in title or artist.
# Skipping song ID 10543121 due to problematic characters in title or artist.
# Skipping song ID 4251690 due to problematic characters in title or artist.
# Skipping song ID 7397483 due to problematic characters in title or artist.
# Skipping song ID 10543229 due to problematic characters in title or artist.
# Skipping song ID 7397652 due to problematic characters in title or artist.
# Skipping song ID 8446316 due to problematic characters in title or artist.
# Skipping song ID 7397765 due to problematic characters in title or artist.
# Skipping song ID 7397767 due to problematic characters in title or artist.
# Skipping song ID 7397773 due to problematic characters in title or artist.
# Skipping song ID 7397772 due to problematic characters in title or artist.
# Skipping song ID 7397775 due to problematic characters in title or artist.
# Error getting details for song ID 10543547: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error getting details for song ID 5300668: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Skipping song ID 10543561 due to problematic characters in title or artist.
# Skipping song ID 9494995 due to problematic characters in title or artist.
# Skipping song ID 7397917 due to problematic characters in title or artist.
# Skipping song ID 8446539 due to problematic characters in title or artist.
# Skipping song ID 8446543 due to problematic characters in title or artist.
# Skipping song ID 8446544 due to problematic characters in title or artist.
# Skipping song ID 8446546 due to problematic characters in title or artist.
# Skipping song ID 9495153 due to problematic characters in title or artist.
# Skipping song ID 57978 due to problematic characters in title or artist.
# Skipping song ID 10543746 due to problematic characters in title or artist.
# Skipping song ID 8446649 due to problematic characters in title or artist.
# Skipping song ID 8446662 due to problematic characters in title or artist.
# Skipping song ID 58065 due to problematic characters in title or artist.
# Skipping song ID 10543860 due to problematic characters in title or artist.
# Skipping song ID 9495294 due to problematic characters in title or artist.
# Skipping song ID 4252486 due to problematic characters in title or artist.
# Skipping song ID 1106784 due to problematic characters in title or artist.
# Skipping song ID 3204013 due to problematic characters in title or artist.
# Skipping song ID 6349778 due to problematic characters in title or artist.
# Skipping song ID 9495606 due to problematic characters in title or artist.
# Skipping song ID 9495643 due to problematic characters in title or artist.
# Skipping song ID 5301416 due to problematic characters in title or artist.
# Skipping song ID 1107128 due to problematic characters in title or artist.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#      10 # Abrufen der Song-Details und Speichern der Checkpoints
#      11 for index, song_id in enumerate(unique_song_ids[processed_songs:], start=processed_songs):
# ---> 12     details = get_song_details(song_id)
#      13     if details:
#      14         song_details_list.append(details)
#
# Cell In[2], line 49, in get_song_details(song_id)
#      47 while retries > 0:
#      48     try:
# ---> 49         song = genius.song(song_id)
#      51         # Abrufen der gewünschten Informationen
#      52         title = song['song']['title']
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/lyricsgenius/api/api.py:437, in API.song(self, song_id, text_format)
#     435 endpoint = "songs/{id}".format(id=song_id)
#     436 params = {'text_format': text_format or self.response_format}
# --> 437 return self._make_request(endpoint, params_=params)
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/lyricsgenius/api/base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      73 tries += 1
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#      81 except Timeout as e:
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Downloads/ML_Scraping/scraping_env/lib/python3.11/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def load_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)

def create_database(db_name):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS songs (
            song_id INTEGER PRIMARY KEY,
            title TEXT,
            artist TEXT,
            release_date TEXT,
            lyrics TEXT,
            album TEXT,
            popularity INTEGER
        )
    ''')
    conn.commit()
    return conn

def insert_song_details(conn, song_details):
    cursor = conn.cursor()
    cursor.execute('''
        INSERT OR IGNORE INTO songs (song_id, title, artist, release_date, lyrics, album, popularity)
        VALUES (?, ?, ?, ?, ?, ?, ?)
    ''', (
        song_details['song_id'],
        song_details['title'],
        song_details['artist'],
        song_details['release_date'],
        song_details['lyrics'],
        song_details['album'],
        song_details['popularity']
    ))
    conn.commit()

# %%
# Lade die JSON-Daten
data = load_json('song_details_checkpoint.json')
song_details_list = data['song_details']

# Erstelle die SQLite-Datenbank
conn = create_database('songs.db')

# Speichere die Daten in der SQLite-Datenbank
for song_details in song_details_list:
    insert_song_details(conn, song_details)

# Schließe die Datenbankverbindung
conn.close()

# %%
def delete_problematic_songs(db_name):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Definiere problematische Zeichen oder Muster
    problematic_chars = ["\u200b", "\u00e4", "\u00f6", "\u00fc", "\u00df"]
    
    for char in problematic_chars:
        cursor.execute('''
            DELETE FROM songs WHERE lyrics LIKE ?
        ''', ('%' + char + '%',))
    
    conn.commit()
    conn.close()

# Bereinige die Daten in der SQLite-Datenbank
delete_problematic_songs('songs.db')
